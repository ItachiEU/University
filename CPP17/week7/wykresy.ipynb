# %%
import seaborn as sb
import pandas as pd
import numpy as np

norm = pd.read_csv('normal.csv')
uni = pd.read_csv('uni.csv')
binomial = pd.read_csv('binom.csv')

# %%
sb.distplot(norm, vertical=True, kde=False)
# Out:
# <AxesSubplot:>

# %%
sb.distplot(uni, vertical=True, kde=False)
# Out:
# <AxesSubplot:>

# %%
sb.distplot(binomial, vertical=True, kde=False)
# Out:
# <AxesSubplot:>
